# %% [markdown]
# [NCBI Gene dataset](https://www.ncbi.nlm.nih.gov/datasets/gene/GCF_000001405.40/) of GRCh38.p14

# %% [markdown]
# ## Build the genes table

# %%
# start an empty df with columns
import pandas as pd
df = pd.DataFrame(columns=[
    "ncbi_gene_id", "symbol", "name", "type", "locus", "transcripts"
])
headers = []
with open("hg38_dataset.tsv") as f:
    for i, line in enumerate(f):
        # Name headers
        if i == 0: 
            headers = line.strip().split("\t")
            continue

        fields = line.strip().split("\t")

        # Make sure the gene id isn't already in the df -- if it is, we'll combine the transcripts
        gene_id = fields[headers.index("Gene ID")]
        if gene_id in df["ncbi_gene_id"].values:
            # I don't know how two rows could have the same Gene ID but no transcripts ?
            # They're V-segments? Biology is complicated
            try: 
                idx = df[df["ncbi_gene_id"] == gene_id].index[0]
                df.loc[idx, "transcripts"].append(fields[headers.index("Transcripts accession")])
            except:
                print("Error with gene id", gene_id)
                pass

        # Otherwise, add a new row
        else:
            row = {
                "ncbi_gene_id": fields[headers.index("Gene ID")],
                "symbol": fields[headers.index("Symbol")],
                "name": fields[headers.index("Name")],
                "type": fields[headers.index("Gene Type")],
                "locus": (fields[headers.index("Chromosome")], 
                        fields[headers.index("Orientation")],
                        int(fields[headers.index("Begin")]),
                        int(fields[headers.index("End")])),
            }
            # Some rows have no transcripts (pseudogenes)
            try:
                row["transcripts"] = [fields[headers.index("Transcripts accession")]]
            except:
                row["transcripts"] = []
            df = pd.concat([df, pd.DataFrame([row])], ignore_index=True)

# Save as tsv (safer for lists etc)
df.to_csv("hg38_genes.tsv", sep="\t", index=False)

# %% [markdown]
# ## Build transcript tables

# %%
import pandas as pd

LINES_PER_FILE = 50000
input_fname = "./hg38_from_ncbi/genomic.gtf"
output_dir = "./server/data/hg38/test_transcripts/" # We'll add the file number and .tsv later
new_file_flag = False
big_file_index = {}
current_file_index = []

df_template = pd.DataFrame(columns=[
    "gene", "transcript", "transcript_bounds", 
    "CDSs", "exons", "start_codon", "stop_codon"])
df = df_template.copy()
with open(input_fname) as f:
    for i, line in enumerate(f):
        line = line.strip()
        if line.startswith("#"):
            continue

        # Build an attribute dictionary
        fields = line.strip().split("\t")
        attributes = fields[8].strip().split(";")
        attributes = attributes[:-1] # Remove the last empty string (ends with a semicolon)
        attributes_dict = {}
        for attr in attributes:
            key, value =  attr.strip().split(" ", 1)
            # There can be multiple values for a key...
            if key in attributes_dict:
                attributes_dict[key] = attributes_dict[key] + "," + value.replace('"', "")
            else:
                attributes_dict[key] = value.replace('"', "")

        # Build a fields dictionary
        headers = ["seqname", "source", "feature", "start", "end", "score", "strand", "frame"]
        fields_dict = dict(zip(headers, fields[:8]))
        
        # Now we do can build the row for the df
        transcript_id = attributes_dict["transcript_id"] # Will be empty string for genes
        if (transcript_id != "") and (transcript_id in df["transcript"].values):
        # New feature on an existing transcript
            current_index = df[df["transcript"] == transcript_id].index[0]
            current_row = df.loc[current_index].to_dict()
        
        elif (transcript_id != ""):
        # New transcript but same gene (presumably these are in order but who knows...)
        # Actually overlapping genes would cause a problem IF they're right at the boundary of files...
        # We'll just make sure that the same gene doesn't apear in multiple files :)
            current_row = {
                "gene": attributes_dict["gene_id"],
                "source": fields_dict["source"],
                "transcript": transcript_id,
                "product": attributes_dict["product"] if "product" in attributes_dict else None,
                "transcript_biotype": attributes_dict["transcript_biotype"],
                "xref": attributes_dict["db_xref"],
                "transcript_bounds": (fields_dict["start"], fields_dict["end"]),
                "CDSs": [],
                "exons": [],
                "start_codon": None,
                "stop_codon": None,
            }
            # Add the row to the df and continue
            df = pd.concat([df, pd.DataFrame([current_row])], ignore_index=True)
            current_index = df.index[-1]
            
        elif (transcript_id == "") and (fields_dict["feature"] == "gene") and (new_file_flag):
        # New gene and we've crossed the file boundary
            # First, move the current_file_index to the big_file_index
            current_file_number = len(big_file_index)
            big_file_index[current_file_number] = current_file_index
            # Then, save the current df
            df.to_csv(f"{output_dir}{current_file_number}.tsv", sep="\t", index=False)
            # Reset the df, and flag!, and current_file_index (don't forget to add the new gene to the index)
            df = df_template.copy()
            current_file_index = [attributes_dict["gene_id"]]
            new_file_flag = False
            continue

        elif (transcript_id == "") and (fields_dict["feature"] == "gene"):
        # New gene but will remain in the same file
            # Add the new gene to the index, but not the df (we only want transcripts)
            current_file_index.append(attributes_dict["gene_id"])
            continue
        else:
            raise ValueError(f"Unknown line: {line}")

        # Populate/update the current row depending on the feature
        feature = fields_dict["feature"]
        if (feature == "transcript"):
            current_row["transcript_bounds"] = (fields_dict["start"], fields_dict["end"])
        elif (feature == "CDS"):
            current_row["CDSs"].append((fields_dict["start"], fields_dict["end"]))
        elif (feature == "exon"):
            current_row["exons"].append((fields_dict["start"], fields_dict["end"]))
        elif (feature == "start_codon"):
            current_row["start_codon"] = (fields_dict["start"], fields_dict["end"])
        elif (feature == "stop_codon"):
            current_row["stop_codon"] = (fields_dict["start"], fields_dict["end"])
        else:
            raise ValueError(f"Unknown feature: {feature}")
            # feature should never be gene, I think?
        
        # Replace the row in the df
        df.loc[current_index] = current_row

        # Save every LINES_PER_FILE rows
        # But pair all transcripts with their gene, so just add a flag until we hit a new gene
        if i % LINES_PER_FILE == 0:
            new_file_flag = True
    
# Save the last file
current_file_number = len(big_file_index)
big_file_index[current_file_number] = current_file_index
df.to_csv(f"{output_dir}{current_file_number}.tsv", sep="\t", index=False)
big_file_index[current_file_number] = current_file_index # And append this to the big index

# Save the big index
reversed_file_index = {} # We want the gene to be the key
for key, value in big_file_index.items():
    for gene in value:
        reversed_file_index[gene] = key
with open(f"{output_dir}index.tsv", "w") as f:
    for key, value in reversed_file_index.items():
        f.write(f"{key}\t{value}\n")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 123
#     121 with open(f"{output_dir}index.tsv", "w") as f:
#     122     for key, value in big_file_index.items():
# --> 123         assert (len(value) == 1) # Each gene should only appear in one file!
#     124         f.write(f"{key}\t{value}\n")
#
# AssertionError:

# %%
# Whoops I forgot to add a header. Read the file and add it
index_fname = "./server/data/hg38/transcripts/index.tsv"
df = pd.read_csv(index_fname, sep="\t", header=None)
df.columns = ["gene_symbol", "file_index"]
df.to_csv(index_fname, sep="\t", index=False)

# %% [markdown]
# ## Build genome sequence files

# %%
INPUT_FASTA = "./hg38_from_ncbi/hg38_genomic.fna"
OUTPUT_DIR = "./server/data/hg38/sequences/"

with open(INPUT_FASTA, "r") as f:
    current_chromosome = None
    current_sequence = []

    for line in f:
        line = line.strip()  # Remove any leading/trailing whitespace
        if line.startswith(">"):  # New header!
            if current_chromosome is not None:
                # Save the previous chromosome sequence to a file (will run every chromosome that's not the first)
                output_file = f"{OUTPUT_DIR}{current_chromosome}.txt"
                with open(output_file, "w", encoding="ascii") as out_f: # ASCII to make sure it's fixed width
                    out_f.write("".join(current_sequence))  # Write the sequence
                print(f"Written: {output_file}")

            current_chromosome = line[1:]  # Extract chromosome name (remove the >)
            current_sequence = []  # Reset the sequence list for the new chromosome
        else:
            current_sequence.append(line)  # Append sequence lines

    # Write the last chromosome if any
    if current_chromosome is not None:
        output_file = f"{OUTPUT_DIR}{current_chromosome}.txt"
        with open(output_file, "w", encoding="ascii") as out_f:
            out_f.write("".join(current_sequence))
        print(f"Written: {output_file}")
# Out:
# Written: ./server/data/hg38/sequences/NC_000001.11 Homo sapiens chromosome 1, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NT_187361.1 Homo sapiens chromosome 1 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR1_CTG1_UNLOCALIZED.txt
# Written: ./server/data/hg38/sequences/NT_187362.1 Homo sapiens chromosome 1 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR1_CTG2_UNLOCALIZED.txt
# Written: ./server/data/hg38/sequences/NT_187363.1 Homo sapiens chromosome 1 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR1_CTG3_UNLOCALIZED.txt
# Written: ./server/data/hg38/sequences/NT_187364.1 Homo sapiens chromosome 1 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR1_CTG4_UNLOCALIZED.txt
# Written: ./server/data/hg38/sequences/NT_187365.1 Homo sapiens chromosome 1 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR1_CTG5_UNLOCALIZED.txt
# Written: ./server/data/hg38/sequences/NT_187366.1 Homo sapiens chromosome 1 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR1_CTG6_UNLOCALIZED.txt
# Written: ./server/data/hg38/sequences/NT_187367.1 Homo sapiens chromosome 1 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR1_CTG7_UNLOCALIZED.txt
# Written: ./server/data/hg38/sequences/NT_187368.1 Homo sapiens chromosome 1 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR1_CTG8_UNLOCALIZED.txt
# Written: ./server/data/hg38/sequences/NT_187369.1 Homo sapiens chromosome 1 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR1_CTG9_UNLOCALIZED.txt
# Written: ./server/data/hg38/sequences/NC_000002.12 Homo sapiens chromosome 2, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NT_187370.1 Homo sapiens chromosome 2 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR2_RANDOM_CTG1.txt
# Written: ./server/data/hg38/sequences/NT_187371.1 Homo sapiens chromosome 2 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR2_RANDOM_CTG2.txt
# Written: ./server/data/hg38/sequences/NC_000003.12 Homo sapiens chromosome 3, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NT_167215.1 Homo sapiens chromosome 3 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR3UN_CTG2.txt
# Written: ./server/data/hg38/sequences/NC_000004.12 Homo sapiens chromosome 4, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NT_113793.3 Homo sapiens chromosome 4 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR4_RANDOM_CTG4.txt
# Written: ./server/data/hg38/sequences/NC_000005.10 Homo sapiens chromosome 5, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NT_113948.1 Homo sapiens chromosome 5 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR5_RANDOM_CTG1.txt
# Written: ./server/data/hg38/sequences/NC_000006.12 Homo sapiens chromosome 6, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NC_000007.14 Homo sapiens chromosome 7, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NC_000008.11 Homo sapiens chromosome 8, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NC_000009.12 Homo sapiens chromosome 9, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NT_187372.1 Homo sapiens chromosome 9 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR9_UNLOCALIZED_CTG1.txt
# Written: ./server/data/hg38/sequences/NT_187373.1 Homo sapiens chromosome 9 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR9_UNLOCALIZED_CTG2.txt
# Written: ./server/data/hg38/sequences/NT_187374.1 Homo sapiens chromosome 9 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR9_UNLOCALIZED_CTG3.txt
# Written: ./server/data/hg38/sequences/NT_187375.1 Homo sapiens chromosome 9 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCHR9_UNLOCALIZED_CTG4.txt
# Written: ./server/data/hg38/sequences/NC_000010.11 Homo sapiens chromosome 10, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NC_000011.10 Homo sapiens chromosome 11, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NC_000012.12 Homo sapiens chromosome 12, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NC_000013.11 Homo sapiens chromosome 13, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NC_000014.9 Homo sapiens chromosome 14, GRCh38.p14 Primary Assembly.txt
# Written: ./server/data/hg38/sequences/NT_113796.3 Homo sapiens chromosome 14 unlocalized genomic scaffold, GRCh38.p14 Primary Assembly HSCH
Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_3 HSCHR19LRC_LRC_I_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187682.1 Homo sapiens chromosome 22 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_3 HSCHR22_3_CTG1.txt
# Written: ./server/data/hg38/sequences/NT_187688.1 Homo sapiens chromosome 3 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_4 HSCHR3_5_CTG3.txt
# Written: ./server/data/hg38/sequences/NT_167246.2 Homo sapiens chromosome 6 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_4 HSCHR6_MHC_MANN_CTG1.txt
# Written: ./server/data/hg38/sequences/NW_003571057.2 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_4 HSCHR19LRC_LRC_J_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187689.1 Homo sapiens chromosome 3 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_5 HSCHR3_6_CTG3.txt
# Written: ./server/data/hg38/sequences/NT_167247.2 Homo sapiens chromosome 6 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_5 HSCHR6_MHC_MCF_CTG1.txt
# Written: ./server/data/hg38/sequences/NW_003571058.2 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_5 HSCHR19LRC_LRC_S_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187690.1 Homo sapiens chromosome 3 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_6 HSCHR3_7_CTG3.txt
# Written: ./server/data/hg38/sequences/NT_167248.2 Homo sapiens chromosome 6 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_6 HSCHR6_MHC_QBL_CTG1.txt
# Written: ./server/data/hg38/sequences/NW_003571059.2 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_6 HSCHR19LRC_LRC_T_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187691.1 Homo sapiens chromosome 3 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_7 HSCHR3_8_CTG3.txt
# Written: ./server/data/hg38/sequences/NT_167249.2 Homo sapiens chromosome 6 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_7 HSCHR6_MHC_SSTO_CTG1.txt
# Written: ./server/data/hg38/sequences/NW_003571060.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_7 HSCHR19LRC_PGF1_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187692.1 Homo sapiens chromosome 6 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_8 HSCHR6_8_CTG1.txt
# Written: ./server/data/hg38/sequences/NW_003571061.2 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_8 HSCHR19LRC_PGF2_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187693.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_9 HSCHR19_4_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187636.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_10 HSCHR19KIR_FH15_B_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187637.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_11 HSCHR19KIR_G085_A_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187638.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_12 HSCHR19KIR_G085_BA1_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187639.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_13 HSCHR19KIR_G248_A_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187640.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_14 HSCHR19KIR_G248_BA2_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187641.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_15 HSCHR19KIR_GRC212_AB_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187642.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_16 HSCHR19KIR_GRC212_BA1_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187643.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_17 HSCHR19KIR_LUCE_A_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187644.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_18 HSCHR19KIR_LUCE_BDEL_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187645.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_19 HSCHR19KIR_RSH_A_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187668.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_20 HSCHR19KIR_RSH_BA2_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187669.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_21 HSCHR19KIR_T7526_A_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187670.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_22 HSCHR19KIR_T7526_BDEL_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187671.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_23 HSCHR19KIR_ABC08_A1_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187672.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_24 HSCHR19KIR_ABC08_AB_HAP_C_P_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187673.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_25 HSCHR19KIR_ABC08_AB_HAP_T_P_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187674.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_26 HSCHR19KIR_FH05_A_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187675.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_27 HSCHR19KIR_FH05_B_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187676.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_28 HSCHR19KIR_FH06_A_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187677.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_29 HSCHR19KIR_FH06_BA1_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187683.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_30 HSCHR19KIR_FH08_A_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187684.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_31 HSCHR19KIR_FH08_BAX_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187685.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_32 HSCHR19KIR_FH13_A_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187686.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_33 HSCHR19KIR_FH13_BA2_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_187687.1 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_34 HSCHR19KIR_FH15_A_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NT_113949.2 Homo sapiens chromosome 19 genomic scaffold, GRCh38.p14 alternate locus group ALT_REF_LOCI_35 HSCHR19KIR_RP5_B_HAP_CTG3_1.txt
# Written: ./server/data/hg38/sequences/NC_012920.1 Homo sapiens mitochondrion, complete genome.txt

# %%
input_fname = "./hg38_from_ncbi/genomic.gtf"
# read like 100 lines for now
lines = []
with open(input_fname) as f:
    for i, line in enumerate(f):
        if i > 100:
            break
        line = line.strip().replace("\t", "     ")
        lines.append(line)

lines
# Out:
# ['#gtf-version 2.2',
#  '#!genome-build GRCh38.p14',
#  '#!genome-build-accession NCBI_Assembly:GCF_000001405.40',
#  '#!annotation-date 08/23/2024',
#  '#!annotation-source NCBI RefSeq GCF_000001405.40-RS_2024_08',
#  'NC_000001.11     BestRefSeq     gene     11874     14409     .     +     .     gene_id "DDX11L1"; transcript_id ""; db_xref "GeneID:100287102"; db_xref "HGNC:HGNC:37102"; description "DEAD/H-box helicase 11 like 1 (pseudogene)"; gbkey "Gene"; gene "DDX11L1"; gene_biotype "transcribed_pseudogene"; pseudo "true";',
#  'NC_000001.11     BestRefSeq     transcript     11874     14409     .     +     .     gene_id "DDX11L1"; transcript_id "NR_046018.2"; db_xref "GeneID:100287102"; db_xref "GenBank:NR_046018.2"; db_xref "HGNC:HGNC:37102"; gbkey "misc_RNA"; gene "DDX11L1"; product "DEAD/H-box helicase 11 like 1 (pseudogene)"; pseudo "true"; transcript_biotype "transcript";',
#  'NC_000001.11     BestRefSeq     exon     11874     12227     .     +     .     gene_id "DDX11L1"; transcript_id "NR_046018.2"; db_xref "GeneID:100287102"; db_xref "GenBank:NR_046018.2"; db_xref "HGNC:HGNC:37102"; gene "DDX11L1"; product "DEAD/H-box helicase 11 like 1 (pseudogene)"; pseudo "true"; transcript_biotype "transcript"; exon_number "1";',
#  'NC_000001.11     BestRefSeq     exon     12613     12721     .     +     .     gene_id "DDX11L1"; transcript_id "NR_046018.2"; db_xref "GeneID:100287102"; db_xref "GenBank:NR_046018.2"; db_xref "HGNC:HGNC:37102"; gene "DDX11L1"; product "DEAD/H-box helicase 11 like 1 (pseudogene)"; pseudo "true"; transcript_biotype "transcript"; exon_number "2";',
#  'NC_000001.11     BestRefSeq     exon     13221     14409     .     +     .     gene_id "DDX11L1"; transcript_id "NR_046018.2"; db_xref "GeneID:100287102"; db_xref "GenBank:NR_046018.2"; db_xref "HGNC:HGNC:37102"; gene "DDX11L1"; product "DEAD/H-box helicase 11 like 1 (pseudogene)"; pseudo "true"; transcript_biotype "transcript"; exon_number "3";',
#  'NC_000001.11     BestRefSeq     gene     14362     29370     .     -     .     gene_id "WASH7P"; transcript_id ""; db_xref "GeneID:653635"; db_xref "HGNC:HGNC:38034"; description "WASP family homolog 7, pseudogene"; gbkey "Gene"; gene "WASH7P"; gene_biotype "transcribed_pseudogene"; gene_synonym "FAM39F"; gene_synonym "WASH5P"; pseudo "true";',
#  'NC_000001.11     BestRefSeq     transcript     14362     29370     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gbkey "misc_RNA"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript";',
#  'NC_000001.11     BestRefSeq     exon     29321     29370     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "1";',
#  'NC_000001.11     BestRefSeq     exon     24738     24891     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "2";',
#  'NC_000001.11     BestRefSeq     exon     18268     18366     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "3";',
#  'NC_000001.11     BestRefSeq     exon     17915     18061     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "4";',
#  'NC_000001.11     BestRefSeq     exon     17606     17742     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "5";',
#  'NC_000001.11     BestRefSeq     exon     17233     17368     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "6";',
#  'NC_000001.11     BestRefSeq     exon     16858     17055     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "7";',
#  'NC_000001.11     BestRefSeq     exon     16607     16765     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "8";',
#  'NC_000001.11     BestRefSeq     exon     15796     15947     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "9";',
#  'NC_000001.11     BestRefSeq     exon     14970     15038     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "10";',
#  'NC_000001.11     BestRefSeq     exon     14362     14829     .     -     .     gene_id "WASH7P"; transcript_id "NR_024540.1"; db_xref "GeneID:653635"; db_xref "GenBank:NR_024540.1"; db_xref "HGNC:HGNC:38034"; gene "WASH7P"; product "WASP family homolog 7, pseudogene"; pseudo "true"; transcript_biotype "transcript"; exon_number "11";',
#  'NC_000001.11     BestRefSeq     gene     17369     17436     .     -     .     gene_id "MIR6859-1"; transcript_id ""; db_xref "GeneID:102466751"; db_xref "HGNC:HGNC:50039"; db_xref "miRBase:MI0022705"; description "microRNA 6859-1"; gbkey "Gene"; gene "MIR6859-1"; gene_biotype "miRNA"; gene_synonym "hsa-mir-6859-1";',
#  'NC_000001.11     BestRefSeq     transcript     17369     17436     .     -     .     gene_id "MIR6859-1"; transcript_id "NR_106918.1"; db_xref "GeneID:102466751"; db_xref "GenBank:NR_106918.1"; db_xref "HGNC:HGNC:50039"; db_xref "miRBase:MI0022705"; gbkey "precursor_RNA"; gene "MIR6859-1"; product "microRNA 6859-1"; transcript_biotype "primary_transcript";',
#  'NC_000001.11     BestRefSeq     exon     17369     17436     .     -     .     gene_id "MIR6859-1"; transcript_id "NR_106918.1"; db_xref "GeneID:102466751"; db_xref "GenBank:NR_106918.1"; db_xref "HGNC:HGNC:50039"; db_xref "miRBase:MI0022705"; gene "MIR6859-1"; product "microRNA 6859-1"; transcript_biotype "primary_transcript"; exon_number "1";',
#  'NC_000001.11     BestRefSeq     transcript     17369     17391     .     -     .     gene_id "MIR6859-1"; transcript_id "unassigned_transcript_1"; db_xref "GeneID:102466751"; db_xref "miRBase:MIMAT0027619"; db_xref "HGNC:HGNC:50039"; db_xref "miRBase:MI0022705"; gbkey "ncRNA"; gene "MIR6859-1"; product "hsa-miR-6859-3p"; transcript_biotype "miRNA";',
#  'NC_000001.11     BestRefSeq     exon     17369     17391     .     -     .     gene_id "MIR6859-1"; transcript_id "unassigned_transcript_1"; db_xref "GeneID:102466751"; db_xref "miRBase:MIMAT0027619"; db_xref "HGNC:HGNC:50039"; db_xref "miRBase:MI0022705"; gene "MIR6859-1"; product "hsa-miR-6859-3p"; transcript_biotype "miRNA"; exon_number "1";',
#  'NC_000001.11     BestRefSeq     transcript     17409     17431     .     -     .     gene_id "MIR6859-1"; transcript_id "unassigned_transcript_2"; db_xref "GeneID:102466751"; db_xref "miRBase:MIMAT0027618"; db_xref "HGNC:HGNC:50039"; db_xref "miRBase:MI0022705"; gbkey "ncRNA"; gene "MIR6859-1"; product "hsa-miR-6859-5p"; transcript_biotype "miRNA";',
#  'NC_000001.11     BestRefSeq     exon     17409     17431     .     -     .     gene_id "MIR6859-1"; transcript_id "unassigned_transcript_2"; db_xref "GeneID:102466751"; db_xref "miRBase:MIMAT0027618"; db_xref "HGNC:HGNC:50039"; db_xref "miRBase:MI0022705"; gene "MIR6859-1"; product "hsa-miR-6859-5p"; transcript_biotype "miRNA"; exon_number "1";',
#  'NC_000001.11     Gnomon     gene     29774     35418     .     +     .     gene_id "MIR1302-2HG"; transcript_id ""; db_xref "GeneID:107985730"; db_xref "HGNC:HGNC:52482"; description "MIR1302-2 host gene"; gbkey "Gene"; gene "MIR1302-2HG"; gene_biotype "lncRNA";',
#  'NC_000001.11     Gnomon     transcript     29774     35418     .     +     .     gene_id "MIR1302-2HG"; transcript_id "XR_007065314.1"; db_xref "GeneID:107985730"; db_xref "GenBank:XR_007065314.1"; db_xref "HGNC:HGNC:52482"; gbkey "ncRNA"; gene "MIR1302-2HG"; model_evidence "Supporting evidence includes similarity to: 1 mRNA, 5 ESTs, 10 long SRA reads, and 96% coverage of the annotated genomic feature by RNAseq alignments, including 4 samples with support for all annotated introns"; product "MIR1302-2 host gene"; transcript_biotype "lnc_RNA";',
#  'NC_000001.11     Gnomon     exon     29774     30667     .     +     .     gene_id "MIR1302-2HG"; transcript_id "XR_007065314.1"; db_xref "GeneID:107985730"; db_xref "GenBank:XR_007065314.1"; db_xref "HGNC:HGNC:52482"; gene "MIR1302-2HG"; model_evidence "Supporting evidence includes similarity to: 1 mRNA, 5 ESTs, 10 long SRA reads, and 96% coverage of the annotated genomic feature by RNAseq alignments, including 4 samples with support for all annotated introns"; product "MIR1302-2 host gene"; transcript_biotype "lnc_RNA"; exon_number "1";',
#  'NC_000001.11     Gnomon     exon     30976     31093     .     +     .     gene_id "MIR1302-2HG"; transcript_id "XR_007065314.1"; db_xref "GeneID:107985730"; db_xref "GenBank:XR_007065314.1"; db_xref "HGNC:HGNC:52482"; gene "MIR1302-2HG"; model_evidence "Supporting evidence includes similarity to: 1 mRNA, 5 ESTs, 10 long SRA reads, and 96% coverage of the annotated genomic feature by RNAseq alignments, including 4 samples with support for all annotated introns"; product "MIR1302-2 host gene"; transcript_biotype "lnc_RNA"; exon_number "2";',
#  'NC_000001.11     Gnomon     exon     34168     35418     .     +     .     gene_id "MIR1302-2HG"; transcript_id "XR_007065314.1"; db_xref "GeneID:107985730"; db_xref "GenBank:XR_007065314.1"; db_xref "HGNC:HGNC:52482"; gene "MIR1302-2HG"; model_evidence "Supporting evidence includes similarity to: 1 mRNA, 5 ESTs, 10 long SRA reads, and 96% coverage of the annotated genomic feature by RNAseq alignments, including 4 samples with support for all annotated introns"; product "MIR1302-2 host gene"; transcript_biotype "lnc_RNA"; exon_number "3";',
#  'NC_000001.11     BestRefSeq     gene     30366     30503     .     +     .     gene_id "MIR1302-2"; transcript_id ""; db_xref "GeneID:100302278"; db_xref "HGNC:HGNC:35294"; db_xref "miRBase:MI0006363"; description "microRNA 1302-2"; gbkey "Gene"; gene "MIR1302-2"; gene_biotype "miRNA"; gene_synonym "hsa-mir-1302-2"; gene_synonym "MIRN1302-2";',
#  'NC_000001.11     BestRefSeq     transcript     30366     30503     .     +     .     gene_id "MIR1302-2"; transcript_id "NR_036051.1"; db_xref "GeneID:100302278"; db_xref "GenBank:NR_036051.1"; db_xref "HGNC:HGNC:35294"; db_xref "miRBase:MI0006363"; gbkey "precursor_RNA"; gene "MIR1302-2"; product "microRNA 1302-2"; transcript_biotype "primary_transcript";',
#  'NC_000001.11     BestRefSeq     exon     30366     30503     .     +     .     gene_id "MIR1302-2"; transcript_id "NR_036051.1"; db_xref "GeneID:100302278"; db_xref "GenBank:NR_036051.1"; db_xref "HGNC:HGNC:35294"; db_xref "miRBase:MI0006363"; gene "MIR1302-2"; product "microRNA 1302-2"; transcript_biotype "primary_transcript"; exon_number "1";',
#  'NC_000001.11     BestRefSeq     transcript     30438     30458     .     +     .     gene_id "MIR1302-2"; transcript_id "unassigned_transcript_3"; db_xref "GeneID:100302278"; db_xref "miRBase:MIMAT0005890"; db_xref "HGNC:HGNC:35294"; db_xref "miRBase:MI0006363"; gbkey "ncRNA"; gene "MIR1302-2"; product "hsa-miR-1302"; transcript_biotype "miRNA";',
#  'NC_000001.11     BestRefSeq     exon     30438     30458     .     +     .     gene_id "MIR1302-2"; transcript_id "unassigned_transcript_3"; db_xref "GeneID:100302278"; db_xref "miRBase:MIMAT0005890"; db_xref "HGNC:HGNC:35294"; db_xref "miRBase:MI0006363"; gene "MIR1302-2"; product "hsa-miR-1302"; transcript_biotype "miRNA"; exon_number "1";',
#  'NC_000001.11     BestRefSeq     gene     34611     36081     .     -     .     gene_id "FAM138A"; transcript_id ""; db_xref "GeneID:645520"; db_xref "HGNC:HGNC:32334"; description "family with sequence similarity 138 member A"; gbkey "Gene"; gene "FAM138A"; gene_biotype "lncRNA"; gene_synonym "F379"; gene_synonym "FAM138F";',
#  'NC_000001.11     BestRefSeq     transcript     34611     36081     .     -     .     gene_id "FAM138A"; transcript_id "NR_026818.1"; db_xref "GeneID:645520"; db_xref "GenBank:NR_026818.1"; db_xref "HGNC:HGNC:32334"; gbkey "ncRNA"; gene "FAM138A"; product "family with sequence similarity 138 member A"; transcript_biotype "lnc_RNA";',
#  'NC_000001.11     BestRefSeq     exon     35721     36081     .     -     .     gene_id "FAM138A"; transcript_id "NR_026818.1"; db_xref "GeneID:645520"; db_xref "GenBank:NR_026818.1"; db_xref "HGNC:HGNC:32334"; gene "FAM138A"; product "family with sequence similarity 138 member A"; transcript_biotype "lnc_RNA"; exon_number "1";',
#  'NC_000001.11     BestRefSeq     exon     35277     35481     .     -     .     gene_id "FAM138A"; transcript_id "NR_026818.1"; db_xref "GeneID:645520"; db_xref "GenBank:NR_026818.1"; db_xref "HGNC:HGNC:32334"; gene "FAM138A"; product "family with sequence similarity 138 member A"; transcript_biotype "lnc_RNA"; exon_number "2";',
#  'NC_000001.11     BestRefSeq     exon     34611     35174     .     -     .     gene_id "FAM138A"; transcript_id "NR_026818.1"; db_xref "GeneID:645520"; db_xref "GenBank:NR_026818.1"; db_xref "HGNC:HGNC:32334"; gene "FAM138A"; product "family with sequence similarity 138 member A"; transcript_biotype "lnc_RNA"; exon_number "3";',
#  'NC_000001.11     Curated Genomic     gene     52453     53396     .     +     .     gene_id "OR4G4P"; transcript_id ""; db_xref "GeneID:79504"; db_xref "HGNC:HGNC:14822"; description "olfactory receptor family 4 subfamily G member 4 pseudogene"; gbkey "Gene"; gene "OR4G4P"; gene_biotype "pseudogene"; pseudo "true";',
#  'NC_000001.11     Curated Genomic     gene     63016     63885     .     +     .     gene_id "OR4G11P"; transcript_id ""; db_xref "GeneID:403263"; db_xref "HGNC:HGNC:31276"; description "olfactory receptor family 4 subfamily G member 11 pseudogene"; gbkey "Gene"; gene "OR4G11P"; gene_biotype "pseudogene"; pseudo "true";',
#  'NC_000001.11     BestRefSeq     gene     65419     71585     .     +     .     gene_id "OR4F5"; transcript_id ""; db_xref "GeneID:79501"; db_xref "HGNC:HGNC:14825"; description "olfactory receptor family 4 subfamily F member 5"; gbkey "Gene"; gene "OR4F5"; gene_biotype "protein_coding";',
#  'NC_000001.11     BestRefSeq     transcript     65419     71585     .     +     .     gene_id "OR4F5"; transcript_id "NM_001005484.2"; db_xref "Ensembl:ENST00000641515.2"; db_xref "GeneID:79501"; db_xref "GenBank:NM_001005484.2"; db_xref "HGNC:HGNC:14825"; gbkey "mRNA"; gene "OR4F5"; product "olfactory receptor family 4 subfamily F member 5"; tag "MANE Select"; transcript_biotype "mRNA";',
#  'NC_000001.11     BestRefSeq     exon     65419     65433     .     +     .     gene_id "OR4F5"; transcript_id "NM_001005484.2"; db_xref "Ensembl:ENST00000641515.2"; db_xref "GeneID:79501"; db_xref "GenBank:NM_001005484.2"; db_xref "HGNC:HGNC:14825"; gene "OR4F5"; product "olfactory receptor family 4 subfamily F member 5"; tag "MANE Select"; transcript_biotype "mRNA"; exon_number "1";',
#  'NC_000001.11     BestRefSeq     exon     65520     65573     .     +     .     gene_id "OR4F5"; transcript_id "NM_001005484.2"; db_xref "Ensembl:ENST00000641515.2"; db_xref "GeneID:79501"; db_xref "GenBank:NM_001005484.2"; db_xref "HGNC:HGNC:14825"; gene "OR4F5"; product "olfactory receptor family 4 subfamily F member 5"; tag "MANE Select"; transcript_biotype "mRNA"; exon_number "2";',
#  'NC_000001.11     BestRefSeq     exon     69037     71585     .     +     .     gene_id "OR4F5"; transcript_id "NM_001005484.2"; db_xref "Ensembl:ENST00000641515.2"; db_xref "GeneID:79501"; db_xref "GenBank:NM_001005484.2"; db_xref "HGNC:HGNC:14825"; gene "OR4F5"; product "olfactory receptor family 4 subfamily F member 5"; tag "MANE Select"; transcript_biotype "mRNA"; exon_number "3";',
#  'NC_000001.11     BestRefSeq     CDS     65565     65573     .     +     0     gene_id "OR4F5"; transcript_id "NM_001005484.2"; db_xref "CCDS:CCDS30547.2"; db_xref "Ensembl:ENSP00000493376.2"; db_xref "GeneID:79501"; db_xref "GenBank:NP_001005484.2"; db_xref "HGNC:HGNC:14825"; gbkey "CDS"; gene "OR4F5"; product "olfactory receptor 4F5"; protein_id "NP_001005484.2"; tag "MANE Select"; exon_number "2";',
#  'NC_000001.11     BestRefSeq     CDS     69037     70005     .     +     0     gene_id "OR4F5"; transcript_id "NM_001005484.2"; db_xref "CCDS:CCDS30547.2"; db_xref "Ensembl:ENSP00000493376.2"; db_xref "GeneID:79501"; db_xref "GenBank:NP_001005484.2"; db_xref "HGNC:HGNC:14825"; gbkey "CDS"; gene "OR4F5"; product "olfactory receptor 4F5"; protein_id "NP_001005484.2"; tag "MANE Select"; exon_number "3";',
#  'NC_000001.11     BestRefSeq     start_codon     65565     65567     .     +     0     gene_id "OR4F5"; transcript_id "NM_001005484.2"; db_xref "CCDS:CCDS30547.2"; db_xref "Ensembl:ENSP00000493376.2"; db_xref "GeneID:79501"; db_xref "GenBank:NP_001005484.2"; db_xref "HGNC:HGNC:14825"; gbkey "CDS"; gene "OR4F5"; product "olfactory receptor 4F5"; protein_id "NP_001005484.2"; tag "MANE Select"; exon_number "2";',
#  'NC_000001.11     BestRefSeq     stop_codon     70006     70008     .     +     0     gene_id "OR4F5"; transcript_id "NM_001005484.2"; db_xref "CCDS:CCDS30547.2"; db_xref "Ensembl:ENSP00000493376.2"; db_xref "GeneID:79501"; db_xref "GenBank:NP_001005484.2"; db_xref "HGNC:HGNC:14825"; gbkey "CDS"; gene "OR4F5"; product "olfactory receptor 4F5"; protein_id "NP_001005484.2"; tag "MANE Select"; exon_number "3";',
#  'NC_000001.11     Gnomon     gene     95222     107727     .     +     .     gene_id "LOC124903816"; transcript_id ""; db_xref "GeneID:124903816"; description "uncharacterized LOC124903816"; gbkey "Gene"; gene "LOC124903816"; gene_biotype "lncRNA";',
#  'NC_000001.11     Gnomon     transcript     95222     107727     .     +     .     gene_id "LOC124903816"; transcript_id "XR_007065337.1"; db_xref "GeneID:124903816"; db_xref "GenBank:XR_007065337.1"; experiment "COORDINATES: polyA evidence [ECO:0006239]"; gbkey "ncRNA"; gene "LOC124903816"; model_evidence "Supporting evidence includes similarity to: 1 EST, 8 long SRA reads, and 84% coverage of the annotated genomic feature by RNAseq alignments, including 2 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X1"; transcript_biotype "lnc_RNA";',
#  'NC_000001.11     Gnomon     exon     95222     99719     .     +     .     gene_id "LOC124903816"; transcript_id "XR_007065337.1"; db_xref "GeneID:124903816"; db_xref "GenBank:XR_007065337.1"; experiment "COORDINATES: polyA evidence [ECO:0006239]"; gene "LOC124903816"; model_evidence "Supporting evidence includes similarity to: 1 EST, 8 long SRA reads, and 84% coverage of the annotated genomic feature by RNAseq alignments, including 2 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X1"; transcript_biotype "lnc_RNA"; exon_number "1";',
#  'NC_000001.11     Gnomon     exon     106636     107727     .     +     .     gene_id "LOC124903816"; transcript_id "XR_007065337.1"; db_xref "GeneID:124903816"; db_xref "GenBank:XR_007065337.1"; experiment "COORDINATES: polyA evidence [ECO:0006239]"; gene "LOC124903816"; model_evidence "Supporting evidence includes similarity to: 1 EST, 8 long SRA reads, and 84% coverage of the annotated genomic feature by RNAseq alignments, including 2 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X1"; transcript_biotype "lnc_RNA"; exon_number "2";',
#  'NC_000001.11     Gnomon     transcript     95222     107727     .     +     .     gene_id "LOC124903816"; transcript_id "XR_007065338.1"; db_xref "GeneID:124903816"; db_xref "GenBank:XR_007065338.1"; experiment "COORDINATES: polyA evidence [ECO:0006239]"; gbkey "ncRNA"; gene "LOC124903816"; model_evidence "Supporting evidence includes similarity to: 1 EST, 8 long SRA reads, and 84% coverage of the annotated genomic feature by RNAseq alignments, including 2 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X2"; transcript_biotype "lnc_RNA";',
#  'NC_000001.11     Gnomon     exon     95222     99719     .     +     .     gene_id "LOC124903816"; transcript_id "XR_007065338.1"; db_xref "GeneID:124903816"; db_xref "GenBank:XR_007065338.1"; experiment "COORDINATES: polyA evidence [ECO:0006239]"; gene "LOC124903816"; model_evidence "Supporting evidence includes similarity to: 1 EST, 8 long SRA reads, and 84% coverage of the annotated genomic feature by RNAseq alignments, including 2 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X2"; transcript_biotype "lnc_RNA"; exon_number "1";',
#  'NC_000001.11     Gnomon     exon     106636     106742     .     +     .     gene_id "LOC124903816"; transcript_id "XR_007065338.1"; db_xref "GeneID:124903816"; db_xref "GenBank:XR_007065338.1"; experiment "COORDINATES: polyA evidence [ECO:0006239]"; gene "LOC124903816"; model_evidence "Supporting evidence includes similarity to: 1 EST, 8 long SRA reads, and 84% coverage of the annotated genomic feature by RNAseq alignments, including 2 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X2"; transcript_biotype "lnc_RNA"; exon_number "2";',
#  'NC_000001.11     Gnomon     exon     106954     107727     .     +     .     gene_id "LOC124903816"; transcript_id "XR_007065338.1"; db_xref "GeneID:124903816"; db_xref "GenBank:XR_007065338.1"; experiment "COORDINATES: polyA evidence [ECO:0006239]"; gene "LOC124903816"; model_evidence "Supporting evidence includes similarity to: 1 EST, 8 long SRA reads, and 84% coverage of the annotated genomic feature by RNAseq alignments, including 2 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X2"; transcript_biotype "lnc_RNA"; exon_number "3";',
#  'NC_000001.11     Gnomon     gene     120849     175246     .     -     .     gene_id "LOC124900384"; transcript_id ""; db_xref "GeneID:124900384"; description "uncharacterized LOC124900384"; gbkey "Gene"; gene "LOC124900384"; gene_biotype "lncRNA";',
#  'NC_000001.11     Gnomon     transcript     120849     175246     .     -     .     gene_id "LOC124900384"; transcript_id "XR_001737579.3"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_001737579.3"; gbkey "ncRNA"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 5 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 34 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X13"; transcript_biotype "lnc_RNA";',
#  'NC_000001.11     Gnomon     exon     173753     175246     .     -     .     gene_id "LOC124900384"; transcript_id "XR_001737579.3"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_001737579.3"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 5 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 34 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X13"; transcript_biotype "lnc_RNA"; exon_number "1";',
#  'NC_000001.11     Gnomon     exon     172557     172688     .     -     .     gene_id "LOC124900384"; transcript_id "XR_001737579.3"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_001737579.3"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 5 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 34 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X13"; transcript_biotype "lnc_RNA"; exon_number "2";',
#  'NC_000001.11     Gnomon     exon     169049     169264     .     -     .     gene_id "LOC124900384"; transcript_id "XR_001737579.3"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_001737579.3"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 5 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 34 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X13"; transcript_biotype "lnc_RNA"; exon_number "3";',
#  'NC_000001.11     Gnomon     exon     168100     168165     .     -     .     gene_id "LOC124900384"; transcript_id "XR_001737579.3"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_001737579.3"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 5 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 34 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X13"; transcript_biotype "lnc_RNA"; exon_number "4";',
#  'NC_000001.11     Gnomon     exon     165884     165942     .     -     .     gene_id "LOC124900384"; transcript_id "XR_001737579.3"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_001737579.3"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 5 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 34 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X13"; transcript_biotype "lnc_RNA"; exon_number "5";',
#  'NC_000001.11     Gnomon     exon     120849     120932     .     -     .     gene_id "LOC124900384"; transcript_id "XR_001737579.3"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_001737579.3"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 5 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 34 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X13"; transcript_biotype "lnc_RNA"; exon_number "6";',
#  'NC_000001.11     Gnomon     transcript     146300     175246     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065328.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065328.1"; gbkey "ncRNA"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 24 long SRA reads, and 76% coverage of the annotated genomic feature by RNAseq alignments, including 19 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X9"; transcript_biotype "lnc_RNA";',
#  'NC_000001.11     Gnomon     exon     173753     175246     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065328.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065328.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 24 long SRA reads, and 76% coverage of the annotated genomic feature by RNAseq alignments, including 19 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X9"; transcript_biotype "lnc_RNA"; exon_number "1";',
#  'NC_000001.11     Gnomon     exon     172557     172688     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065328.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065328.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 24 long SRA reads, and 76% coverage of the annotated genomic feature by RNAseq alignments, including 19 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X9"; transcript_biotype "lnc_RNA"; exon_number "2";',
#  'NC_000001.11     Gnomon     exon     169049     169264     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065328.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065328.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 24 long SRA reads, and 76% coverage of the annotated genomic feature by RNAseq alignments, including 19 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X9"; transcript_biotype "lnc_RNA"; exon_number "3";',
#  'NC_000001.11     Gnomon     exon     168100     168165     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065328.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065328.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 24 long SRA reads, and 76% coverage of the annotated genomic feature by RNAseq alignments, including 19 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X9"; transcript_biotype "lnc_RNA"; exon_number "4";',
#  'NC_000001.11     Gnomon     exon     165884     165942     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065328.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065328.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 24 long SRA reads, and 76% coverage of the annotated genomic feature by RNAseq alignments, including 19 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X9"; transcript_biotype "lnc_RNA"; exon_number "5";',
#  'NC_000001.11     Gnomon     exon     164263     164791     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065328.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065328.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 24 long SRA reads, and 76% coverage of the annotated genomic feature by RNAseq alignments, including 19 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X9"; transcript_biotype "lnc_RNA"; exon_number "6";',
#  'NC_000001.11     Gnomon     exon     158593     158674     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065328.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065328.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 24 long SRA reads, and 76% coverage of the annotated genomic feature by RNAseq alignments, including 19 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X9"; transcript_biotype "lnc_RNA"; exon_number "7";',
#  'NC_000001.11     Gnomon     exon     155767     155831     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065328.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065328.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 24 long SRA reads, and 76% coverage of the annotated genomic feature by RNAseq alignments, including 19 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X9"; transcript_biotype "lnc_RNA"; exon_number "8";',
#  'NC_000001.11     Gnomon     exon     146300     146339     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065328.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065328.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 24 long SRA reads, and 76% coverage of the annotated genomic feature by RNAseq alignments, including 19 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X9"; transcript_biotype "lnc_RNA"; exon_number "9";',
#  'NC_000001.11     Gnomon     transcript     146301     175246     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gbkey "ncRNA"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA";',
#  'NC_000001.11     Gnomon     exon     173753     175246     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA"; exon_number "1";',
#  'NC_000001.11     Gnomon     exon     172557     172688     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA"; exon_number "2";',
#  'NC_000001.11     Gnomon     exon     169049     169264     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA"; exon_number "3";',
#  'NC_000001.11     Gnomon     exon     168100     168165     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA"; exon_number "4";',
#  'NC_000001.11     Gnomon     exon     165884     165942     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA"; exon_number "5";',
#  'NC_000001.11     Gnomon     exon     164263     164791     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA"; exon_number "6";',
#  'NC_000001.11     Gnomon     exon     158593     158674     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA"; exon_number "7";',
#  'NC_000001.11     Gnomon     exon     155767     155831     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA"; exon_number "8";',
#  'NC_000001.11     Gnomon     exon     153354     153543     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA"; exon_number "9";',
#  'NC_000001.11     Gnomon     exon     146301     146339     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065325.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065325.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 4 ESTs, 25 long SRA reads, and 78% coverage of the annotated genomic feature by RNAseq alignments, including 14 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X6"; transcript_biotype "lnc_RNA"; exon_number "10";',
#  'NC_000001.11     Gnomon     transcript     146435     175246     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065330.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065330.1"; gbkey "ncRNA"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 1 EST, 25 long SRA reads, and 75% coverage of the annotated genomic feature by RNAseq alignments, including 58 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X11"; transcript_biotype "lnc_RNA";',
#  'NC_000001.11     Gnomon     exon     173753     175246     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065330.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065330.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 1 EST, 25 long SRA reads, and 75% coverage of the annotated genomic feature by RNAseq alignments, including 58 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X11"; transcript_biotype "lnc_RNA"; exon_number "1";',
#  'NC_000001.11     Gnomon     exon     172557     172688     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065330.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065330.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 1 EST, 25 long SRA reads, and 75% coverage of the annotated genomic feature by RNAseq alignments, including 58 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X11"; transcript_biotype "lnc_RNA"; exon_number "2";',
#  'NC_000001.11     Gnomon     exon     169049     169264     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065330.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065330.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 1 EST, 25 long SRA reads, and 75% coverage of the annotated genomic feature by RNAseq alignments, including 58 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X11"; transcript_biotype "lnc_RNA"; exon_number "3";',
#  'NC_000001.11     Gnomon     exon     168100     168165     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065330.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065330.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 1 EST, 25 long SRA reads, and 75% coverage of the annotated genomic feature by RNAseq alignments, including 58 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X11"; transcript_biotype "lnc_RNA"; exon_number "4";',
#  'NC_000001.11     Gnomon     exon     165884     165942     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065330.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065330.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 1 EST, 25 long SRA reads, and 75% coverage of the annotated genomic feature by RNAseq alignments, including 58 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X11"; transcript_biotype "lnc_RNA"; exon_number "5";',
#  'NC_000001.11     Gnomon     exon     164263     164791     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065330.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065330.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 1 EST, 25 long SRA reads, and 75% coverage of the annotated genomic feature by RNAseq alignments, including 58 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X11"; transcript_biotype "lnc_RNA"; exon_number "6";',
#  'NC_000001.11     Gnomon     exon     155767     155831     .     -     .     gene_id "LOC124900384"; transcript_id "XR_007065330.1"; db_xref "GeneID:124900384"; db_xref "GenBank:XR_007065330.1"; gene "LOC124900384"; model_evidence "Supporting evidence includes similarity to: 1 EST, 25 long SRA reads, and 75% coverage of the annotated genomic feature by RNAseq alignments, including 58 samples with support for all annotated introns"; product "uncharacterized lncRNA, transcript variant X11"; transcript_biotype "lnc_RNA"; exon_number "7";']

# %%
test = "abcdedfghijklmnopqrstuvwxyz"
test[0:3]
# Out:
# 'abc'

# %%
# I want to know all the differnt biotypes in the gtf file
input_fname = "./hg38_from_ncbi/genomic.gtf"
biotypes = set()
with open(input_fname, "r") as f:
    for line in f:
        if line.startswith("#"):
            continue
        fields = line.strip().split("\t")
        attributes = fields[8].strip().split(";")
        attributes = attributes[:-1] # Remove the last empty string (ends with a semicolon)
        attributes_dict = {}
        for attr in attributes:
            key, value =  attr.strip().split(" ", 1)
            if key == "transcript_biotype":
                biotypes.add(value.replace('"', ""))

biotypes
# Out:
# {'C_gene_segment',
#  'D_gene_segment',
#  'J_gene_segment',
#  'RNase_MRP_RNA',
#  'RNase_P_RNA',
#  'V_gene_segment',
#  'Y_RNA',
#  'antisense_RNA',
#  'lnc_RNA',
#  'mRNA',
#  'miRNA',
#  'ncRNA',
#  'primary_transcript',
#  'rRNA',
#  'scRNA',
#  'snRNA',
#  'snoRNA',
#  'tRNA',
#  'telomerase_RNA',
#  'transcript',
#  'vault_RNA'}
